# %%
import seaborn as sns
import matplotlib.pyplot as plt

# LOAD THE "tips" DATA SET .

plt.style.use("fivethirtyeight")
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# PLOT THE BAR PLOT FOR COLUMN "smoker" AS X-AXIS AND COLUMN "tip" AS Y-AXIS USING catplot() .

sns.catplot ( x="smoker" , y="tip" , kind="bar" , data=df )

# %%
# PLOT THE BAR PLOT FOR COLUMN "smoker" AS X-AXIS AND COLUMN "total_bill" AS Y-AXIS USING catplot() .

sns.catplot ( x="smoker" , y="total_bill" , kind="bar" , data=df )

# %%
''' 
PLOT THE BAR PLOT FOR COLUMN "smoker" AS X-AXIS AND COLUMN "total_bill" AS Y-AXIS USING catplot() 
USING hue PARAMETER AS COLUMN "sex".
'''

sns.catplot ( x="smoker" , y="total_bill" , hue="sex" , kind="bar" , data=df )

# %%
import numpy as np
sns.catplot ( x="smoker" , y="total_bill" , hue="sex" , kind="bar" , estimator=np.mean , data=df )

# %%
import numpy as np
sns.catplot ( x="smoker" , y="total_bill" , hue="sex" , kind="bar" , estimator=np.median , data=df )

# %%
import numpy as np
sns.catplot ( x="smoker" , y="total_bill" , hue="sex" , kind="bar" , estimator=np.std , data=df )

# %%
import numpy as np
sns.catplot ( x="smoker" , y="total_bill" , hue="sex" , kind="bar" , estimator=np.var , data=df )

# %%
''' 
PLOT THE BAR PLOT FOR COLUMN "day" AS X-AXIS AND COLUMN "total_bill" AS Y-AXIS USING catplot() 
USING hue PARAMETER AS COLUMN "sex".
'''

sns.catplot ( x="day" , y="total_bill" , hue="sex" , kind="bar" , data=df )

# %%
''' 
PLOT THE BAR PLOT FOR COLUMN "day" AS X-AXIS AND COLUMN "total_bill" AS Y-AXIS USING barplot() 
USING hue PARAMETER AS COLUMN "sex".
'''

sns.barplot ( x="day" , y="total_bill" , hue="sex" , data=df )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# PLOT THE COUNT PLOT FOR COLUMN "sex" AS X-AXIS USING catplot() .

sns.catplot ( x="sex" , kind="count" , data=df )

# %%
# PLOT THE COUNT PLOT FOR COLUMN "sex" AS X-AXIS USING catplot() USING hue PARAMETER AS COLUMN "smoker".

sns.catplot ( x="sex" , hue="smoker" , kind="count" , data=df )

# %%
# PLOT THE COUNT PLOT FOR COLUMN "day" AS X-AXIS USING catplot() USING hue PARAMETER AS COLUMN "sex".

sns.catplot ( x="day" , hue="sex" , kind="count" , data=df )

# %%
''' 
PLOT THE COUNT PLOT FOR COLUMN "sex" AS X-AXIS USING countplot() 
USING hue PARAMETER AS COLUMN "smoker" .
'''

sns.countplot ( x="sex" , hue="smoker" , data=df )
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
''' 
PLOT THE COUNT PLOT FOR COLUMN "day" AS X-AXIS USING countplot() 
USING hue PARAMETER AS COLUMN "sex" .
'''

sns.countplot ( x="day" , hue="sex" , data=df )
# Out:
# <Axes: xlabel='day', ylabel='count'>
